# %% [markdown]
# # Edge Detection Assignment
#
# - Study OpenCV api, focusing on Canny, Sobel and Laplacian edge detectors.
# - Do exercises below, and return a zip containing both this ipynb file and images.
# - Make sure the notebook has the execution outputs included as well.

# %%
#imports

# %% [markdown]
# ## Canny edge detection and smoothing
# - a) Use Canny edge detector, and compare raw image and smoothed image. Use smoothing filter you find the best for the use case. Write conclusions of selecting smoothing filter and screenshots.

# %%
# code

# %% [markdown]
# ## Sobel operator X-direction and Y-direction
#
# - b) Use Sobel operator to detect separately X-direction and Y-direction. Draw original, X, Y and combined. Write conclusions about filter operation.

# %%
# code

# %% [markdown]
# ## Laplacian filter
#
# -   c) Use Laplacian filter with kernel sizes 3 5 and 7, and write down observations. Include screenshots.

# %%
# code

# %% [markdown]
# ## Compare Canny, Sobel and Laplacian
#
# -   d) Compare 3 previous edge detection algorithms and write down conclusions.

# %%
# code

# %% [markdown]
# ## Bonus: Drain Pipe Lines Real Life Example
#
# -   e) What kind of edge detection pipeline would you use on detached house or apartment building drawings, when the goal is to detect the drain pipe lines out of all the noise and other information. Use the 3 examples images as test environment. Write down your reasoning. Goal is to simply find out the drain pipes as efficiently as possible.

# %%
# code
